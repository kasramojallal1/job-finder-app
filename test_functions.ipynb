# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./datasets/freelance-projects.csv')
df.head(3)
# Out:
#                                    Title         Category Name Experience  \
# 0  Banner images for web desgin websites                Design  Entry ($)
# 1    Make my picture a solid silhouette   Video, Photo & Image  Entry ($)
# 2                      Bookkeeper needed              Business  Entry ($)
#
#       Sub Category Name Currency  Budget Location Freelancer Preferred From  \
# 0        Graphic Design      EUR    60.0   remote                       ALL
# 1         Image Editing      GBP    20.0   remote                       ALL
# 2  Finance & Accounting      GBP    12.0   remote                       ALL
#
#           Type          Date Posted  \
# 0  fixed_price  2023-04-29 18:06:39
# 1  fixed_price  2023-04-29 17:40:28
# 2  fixed_price  2023-04-29 17:40:06
#
#                                          Description Duration  \
# 0  We are looking to improve the banner images on...      NaN
# 1  Hello \n\nI need a quick designer to make 4 pi...      NaN
# 2  Hi - I need a bookkeeper to assist with bookke...      NaN
#
#   Client Registration Date Client City  Client Country Client Currency  \
# 0               2010-11-03      Dublin         Ireland             EUR
# 1               2017-02-21      London  United Kingdom             GBP
# 2               2023-04-09      London  United Kingdom             GBP
#
#   Client Job Title
# 0   PPC Management
# 1   Office manager
# 2        Paralegal

# %%
df = df.drop(['Date Posted', 'Freelancer Preferred From', 'Duration'], axis=1)
df = df.filter(regex=r'^(?!.*Client).*$', axis=1)

experience_mapping = {'Entry ($)': 1, 'Intermediate ($$)': 2, 'Expert ($$$)': 3}
df['Experience'] = df['Experience'].map(experience_mapping)

df.head(3)
# Out:
#                                    Title         Category Name  Experience  \
# 0  Banner images for web desgin websites                Design           1
# 1    Make my picture a solid silhouette   Video, Photo & Image           1
# 2                      Bookkeeper needed              Business           1
#
#       Sub Category Name Currency  Budget Location         Type  \
# 0        Graphic Design      EUR    60.0   remote  fixed_price
# 1         Image Editing      GBP    20.0   remote  fixed_price
# 2  Finance & Accounting      GBP    12.0   remote  fixed_price
#
#                                          Description
# 0  We are looking to improve the banner images on...
# 1  Hello \n\nI need a quick designer to make 4 pi...
# 2  Hi - I need a bookkeeper to assist with bookke...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

def preprocess_text(text):

    text = text.lower()
    
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    
    tokens = word_tokenize(text)

    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    clean_text = ' '.join(tokens)
    
    return clean_text


df['Clean Description'] = df['Description'].apply(preprocess_text)
df['Clean Description']
# Out:
# 0        looking improve banner images web design pages...
# 1        hello need quick designer make 4 pictures soli...
# 2             hi need bookkeeper assist bookkeeping thanks
# 3        hi need accountant assist understanding regula...
# 4        hi currently running project require 100 guest...
#                                ...
# 12217    looking published travel writer write articles...
# 12218    website wwwjuicebitzcouk added filters usb cab...
# 12219       need someone write quick sql query basic table
# 12220    seeking full stack web developer specializes c...
# 12221    hi following administrative task would appreci...
# Name: Clean Description, Length: 12222, dtype: object

# %%
df.head(3)
# Out:
#                                    Title         Category Name  Experience  \
# 0  Banner images for web desgin websites                Design           1
# 1    Make my picture a solid silhouette   Video, Photo & Image           1
# 2                      Bookkeeper needed              Business           1
#
#       Sub Category Name Currency  Budget Location         Type  \
# 0        Graphic Design      EUR    60.0   remote  fixed_price
# 1         Image Editing      GBP    20.0   remote  fixed_price
# 2  Finance & Accounting      GBP    12.0   remote  fixed_price
#
#                                          Description  \
# 0  We are looking to improve the banner images on...
# 1  Hello \n\nI need a quick designer to make 4 pi...
# 2  Hi - I need a bookkeeper to assist with bookke...
#
#                                    Clean Description
# 0  looking improve banner images web design pages...
# 1  hello need quick designer make 4 pictures soli...
# 2       hi need bookkeeper assist bookkeeping thanks

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def merge_subword_tokens(ner_results):
        new_results = []
        for item in ner_results:
            if item['word'].startswith('##'):
                if new_results:
                    new_results[-1]['word'] = new_results[-1]['word'] + item['word'][2:]
                    new_results[-1]['end'] = item['end']
            else:
                new_results.append(item)
        return new_results

# %%
def extract_entities(text):

    entity_words = []
    ner_results = nlp(text)
    merged_results = merge_subword_tokens(ner_results)

    for entity in merged_results:
        entity_words.append(entity['word'])

    result = ', '.join(entity_words)

    return result

# %%
text = """We are looking for a Data Scientist with expertise in machine learning, deep learning, and statistics. 
Skills required: Python, TensorFlow, SQL, and experience with cloud services like AWS or Azure."""

extract_entities(text)
# Out:
# 'Data, Scientist, Python, TensorFlow, SQL, AWS, Azure'

# %%
text = df.loc[0, 'Clean Description']
print(text)
# Out:
# looking improve banner images web design pages web design shopify woo commence redesign ecommerce wwwleapdigitalie attaching two images like create images similar design

# %%
import pandas as pd

df2 = pd.read_csv('output.csv')
non_empty_skills = df2[df2['Skills'].notnull()]
non_empty_skills['Skills']
# Out:
# 137           httpsgonppcom
# 218              ohdoshcouk
# 334                      sa
# 402      httpsbapasmealscom
# 511                   angel
#                 ...
# 11685              medicare
# 11691        httpsmosinecom
# 11851           justhostcom
# 12043                xtemos
# 12201       densbergensberg
# Name: Skills, Length: 124, dtype: object

# %%
for index, row in df.head(10).iterrows():
    text = row['Description']
    entities = extract_entities(text)
    print(f"Row {index}: {entities}")
# Out:
# Row 0: Shopify
# Row 1:
# Row 2:
# Row 3: UK
# Row 4: D, Doow, No, AI, AI, AI, Macworld, CNBC, Wondersha, Cnet, Tribune, India, Digital, Trends, Techno, B, PC, Mag, tech, Techtarget, The, Windows, Club, MSN, Daily, Star, CO, UK, Forbes, Council, Post, FAST, Company, YEC, Council, Post, Moz, DA, AREFS, DR, SA
# Row 5: Database, Google, Drive
# Row 6:
# Row 7: UK, UK
# Row 8: LGBTQ
# Row 9: US, UK, CA

# %%
from tqdm import tqdm

df['Ex-Skills'] = ''

for index, row in tqdm(df.iterrows(), total=len(df), desc='Processing'):
    text = row['Description']
    entities = extract_entities(text)
    df.at[index, 'Ex-Skills'] = entities
# Out:
# Processing: 100%|██████████| 12222/12222 [52:58<00:00,  3.84it/s]

# %%
df.to_csv('output_2.csv', index=False)

# %%
df.head(10)
# Out:
#                                                Title  \
# 0              Banner images for web desgin websites
# 1                Make my picture a solid silhouette
# 2                                  Bookkeeper needed
# 3                                 Accountant needed
# 4                      Guest Post on High DA Website
# 5        Content Database Project for Travel Company
# 6                 Make web site for Tutoring company
# 7                 Seeking Highly Skilled Freelancers
# 8                                         E-learning
# 9  19 sentences recording. native english speaker...
#
#               Category Name  Experience          Sub Category Name Currency  \
# 0                    Design           1             Graphic Design      EUR
# 1      Video, Photo & Image           1              Image Editing      GBP
# 2                  Business           1       Finance & Accounting      GBP
# 3                  Business           1  Tax Consulting & Advising      GBP
# 4         Digital Marketing           3                        SEO      USD
# 5  Technology & Programming           3                  Databases      EUR
# 6                    Design           1                 Web Design      USD
# 7  Technology & Programming           1        Website Development      GBP
# 8                    Design           2     Illustration & Drawing      GBP
# 9             Music & Audio           1                 Voice-Over      USD
#
#     Budget Location         Type  \
# 0     60.0   remote  fixed_price
# 1     20.0   remote  fixed_price
# 2     12.0   remote  fixed_price
# 3     14.0   remote  fixed_price
# 4  10000.0   remote  fixed_price
# 5    500.0   remote  fixed_price
# 6     10.0   remote  fixed_price
# 7     10.0   remote  fixed_price
# 8      0.0   remote  fixed_price
# 9     10.0   remote  fixed_price
#
#                                          Description  \
# 0  We are looking to improve the banner images on...
# 1  Hello \n\nI need a quick designer to make 4 pi...
# 2  Hi - I need a bookkeeper to assist with bookke...
# 3  Hi - I need an accountant to assist me with un...
# 4  Hi, I am currently running a project where I w...
# 5  Brief\nThe requirements of this brief is to fi...
# 6  I need to build web site for my tutoring compa...
# 7  I am currently working on a new freelancer com...
# 8  Looking for a quote for an introductory e-lear...
# 9  1.  need native speaker from US or UK or CA\n2...
#
#                                    Clean Description Skills Entities  \
# 0  looking improve banner images web design pages...
# 1  hello need quick designer make 4 pictures soli...
# 2       hi need bookkeeper assist bookkeeping thanks
# 3  hi need accountant assist understanding regula...
# 4  hi currently running project require 100 guest...
# 5  brief requirements brief find solution manage ...             NaN
# 6  need build web site tutoring company simple de...             NaN
# 7  currently working new freelancer community pro...             NaN
# 8  looking quote introductory elearniing course c...             NaN
# 9  1 need native speaker us uk ca 2 one read 19 s...             NaN
#
#                                            Ex-Skills
# 0                                            Shopify
# 1
# 2
# 3                                                 UK
# 4  D, Doow, No, AI, AI, AI, Macworld, CNBC, Wonde...
# 5                            Database, Google, Drive
# 6
# 7                                             UK, UK
# 8                                              LGBTQ
# 9                                         US, UK, CA
